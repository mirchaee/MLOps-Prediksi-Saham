# %%
import yfinance as yf
import pandas as pd
import numpy as np

ticker = "BBCA.JK"
df = yf.download(ticker, start="2024-01-01", end="2026-01-01")

print(f"--- Data Summary {ticker} ---")
print(df.info())
print("\n--- 5 Data Terakhir ---")
print(df.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
# --- Data Summary BBCA.JK ---
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 473 entries, 2024-01-02 to 2025-12-30
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Close, BBCA.JK)   473 non-null    float64
#  1   (High, BBCA.JK)    473 non-null    float64
#  2   (Low, BBCA.JK)     473 non-null    float64
#  3   (Open, BBCA.JK)    473 non-null    float64
#  4   (Volume, BBCA.JK)  473 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 22.2 KB
# None
#
# --- 5 Data Terakhir ---
# Price             Close         High          Low         Open     Volume
# Ticker          BBCA.JK      BBCA.JK      BBCA.JK      BBCA.JK    BBCA.JK
# Date
# 2025-12-22  7801.898438  7801.898438  7658.744338  7682.603354   72424200
# 2025-12-23  7658.744141  7754.180205  7611.026109  7730.321189   85044100
# 2025-12-24  7658.744141  7706.462173  7634.885125  7658.744141   71260500
# 2025-12-29  7658.744141  7658.744141  7587.167093  7658.744141   78399400
# 2025-12-30  7706.462402  7801.898469  7587.167319  7587.167319  101995600
